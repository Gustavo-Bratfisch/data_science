# %% [markdown]
# # Projeto de Data Engineering Simples
# Nesse projeto iremos fazer o Data Engineering basico, onde pegamos os dados da pagina de livros http://books.toscrape.com/ (essa pagina foi feita para fazer e praticar o web scraping). Para coletarmos os dados vamos utilizar o pacote BeautifulSOup e para clicar/trocar de paginas usamos o Selenium.
#
# Nesse site de livros, inicialmente eu coletei todas as urls de todos os mil livros, com essas Url's fiz a coleta do nome do livro, o preço que o livro está custando, a avaliação feita do livro em formato de estrelas (de 1-5), o tipo/gênero do livro e por fim se o livro estava no estoque. Além disso criei uma tabela dentro de um banco de dados para alimentar em cada iteração (nesse caso estou utilizando SQL Server) e por fim temos nosso Data frame que tambem exportamos para csv.
#
# Só para mostrar o conjunto final dos dados, eu fiz alguns plots e analises breves para mostrar como ficaram esses valores.

# %% [markdown]
# ## Coletando os Dados

# %%
#Bibliotecas importantes

from selenium import webdriver
from selenium.webdriver.firefox.firefox_binary import FirefoxBinar
#Bibliotecas para fazer web scrapy dos sites
import requests
from requests import get
from bs4 import BeautifulSoup

#trabalhar com data frame
import pandas as pd

#Biblioteca para o processamento de linguagem
import re
import nltk
#nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.util import bigrams

# %%
#Utilizando o FireFox para automatizar a passagem de paginas com o Selenium
binary = FirefoxBinary('C:\\Program Files\\Mozilla Firefox\\firefox.exe')

driver = webdriver.Firefox(firefox_binary=binary, executable_path=r'C:\\geckodriver.exe')

# %%
#Iremos encontrando dentro do HTML da pagina todas as URL's que levam para as paginas dos livros em si, 
#utilizando BeautifulSoup

driver.get('http://books.toscrape.com/')

sites = []
soup = BeautifulSoup(driver.page_source)

categories = soup.find_all('div', class_="side_categories")
todas_cat = []
aux_cat = categories[0].find_all('li')
for i in range(1,len(aux_cat)):
    todas_cat.append(aux_cat[i].text.replace('\n','').replace(' ',''))


aux_numbepages = soup.find_all('ul', class_='pager')
aux_numbepages2 = aux_numbepages[0].find_all('li', class_ = 'current')

aux_numbepages3 = aux_numbepages2[0].text.replace('\n','').replace(' ','').replace('Page','').replace('of','')

total_pages = int(aux_numbepages3[1:])
page = int(aux_numbepages3[:-2])

#Um loop para percorrer o numero total de paginas (total_pages), pois cada pagina disponibiliza 20 livros.
for i in range(page,total_pages):
    div_sit = soup.find_all('div', class_='image_container')
    for i in range(0,len(div_sit)):
        aux = div_sit[i].find('a',href = True)
        sit_name = aux['href'].replace('catalogue','')
        sites.append('http://books.toscrape.com/catalogue/' + sit_name)
    
    submit_button  = driver.find_element_by_xpath('//li[@class="next"]//a')
    submit_button.click()
    soup = BeautifulSoup(driver.page_source)

div_sit = soup.find_all('div', class_='image_container')

#Esse loop final é para pegar a ultima pagina do nosso site.
for i in range(0,len(div_sit)):
    aux = div_sit[i].find('a',href = True)
    sit_name = aux['href'].replace('catalogue','')
    #print(sit_name)
    sites.append('http://books.toscrape.com/catalogue/' + sit_name)

# %%
#Função para troca o numero escrito para o numerico em si
def chang_est(word):
    if(word[:7] == 'Instock'):
        return('Sim')
    else:
        return('Nao')

# %% [markdown]
# Conectando e criando uma tabela no SQL Server 2014

# %%
#Mostrando a criação da tabela dentro odo banco de dados
import pyodbc 
# Some other example server values are
# server = 'localhost\sqlexpress' # for a named instance
# server = 'myserver,port' # to specify an alternate port
server = 'DESKTOP-D2A5BFQ\SQLEXPRESS' 
database = 'projeto' 
username =  ''
password = '' 
cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)
cursor = cnxn.cursor()

cursor.execute('''
                CREATE TABLE LIVROS
                (
                IDLIVRO INT PRIMARY KEY IDENTITY,
                NOME VARCHAR(300),
                PRECO MONEY,
                ESTOQUE CHAR(3),
                ESTILO VARCHAR(30),
                AVALIACAO INT
                )

''')
cursor.commit()

# %% [markdown]
# Coletando os dados desejado dentro de cada URL encontrada anteriormente, inserindo dentro de arrays vazios. Por fim alimentamos nos banco de dados.

# %%
titulo = []
preco = []
estoque = []
estilo = []
avaliacao = []
num2words = {'One':1,'Two' : 2,'Three': 3, 'Four':4,'Five':5}

for j in range(0,len(sites)):
    results = requests.get(sites[j])
    soup2 = BeautifulSoup(results.text, "html.parser")

    div_carct = soup2.find_all('div',  class_='col-sm-6 product_main')

    p_carct = div_carct[0].find_all('p')

    tit = div_carct[0].find_all('h1')[0].text
    pre = float(p_carct[0].text[2:])
    stoq = chang_est(p_carct[1].text.replace('\n','').replace(' ',''))
    estre = num2words[p_carct[2]['class'][1]]
    
    ul_est = soup2.find_all('ul', class_='breadcrumb')
    
    for litag in ul_est[0].find_all('li'):
        if litag.text.replace('\n','').replace(' ','') in todas_cat:
            stilo = litag.text.replace('\n','')

    titulo.append(tit)
    preco.append(pre)
    estoque.append(stoq)
    avaliacao.append(estre)
    estilo.append(stilo)

#Aqui inserimos nosso dados dentro de um banco de dados
    #values = (tit,pre,stoq,tex,estre)
    #insert_query = '''INSERT INTO LIVROS (NOME,PRECO,ESTOQUE,ESTILO,AVALIACAO)
    #              VALUES (?,?,?,?,?)'''
    #cursor.execute(insert_query,values)
    #cursor.commit()

# %% [markdown]
# Mostrando como ficou no final nosso banco de dados

# %%
cursor.execute('SELECT * FROM LIVROS')

for row in cursor:
    print(row)
# Out:
# (1, 'A Light in the Attic', Decimal('51.7700'), 'Sim', 'Food and Drink', 3)
# (2, 'Tipping the Velvet', Decimal('53.7400'), 'Sim', 'Food and Drink', 1)
# (3, 'Soumission', Decimal('50.1000'), 'Sim', 'Food and Drink', 1)
# (4, 'Sharp Objects', Decimal('47.8200'), 'Sim', 'Food and Drink', 4)
# (5, 'Sapiens: A Brief History of Humankind', Decimal('54.2300'), 'Sim', 'Food and Drink', 5)
# (6, 'The Requiem Red', Decimal('22.6500'), 'Sim', 'Food and Drink', 1)
# (7, 'The Dirty Little Secrets of Getting Your Dream Job', Decimal('33.3400'), 'Sim', 'Food and Drink', 4)
# (8, 'The Coming Woman: A Novel Based on the Life of the Infamous Feminist, Victoria Woodhull', Decimal('17.9300'), 'Sim', 'Food and Drink', 3)
# (9, 'The Boys in the Boat: Nine Americans and Their Epic Quest for Gold at the 1936 Berlin Olympics', Decimal('22.6000'), 'Sim', 'Food and Drink', 4)
# (10, 'The Black Maria', Decimal('52.1500'), 'Sim', 'Food and Drink', 1)
# (11, 'Starving Hearts (Triangular Trade Trilogy, #1)', Decimal('13.9900'), 'Sim', 'Food and Drink', 2)
# (12, "Shakespeare's Sonnets", Decimal('20.6600'), 'Sim', 'Food and Drink', 4)
# (13, 'Set Me Free', Decimal('17.4600'), 'Sim', 'Food and Drink', 5)
# (14, "Scott Pilgrim's Precious Little Life (Scott Pilgrim #1)", Decimal('52.2900'), 'Sim', 'Food and Drink', 5)
# (15, 'Rip it Up and Start Again', Decimal('35.0200'), 'Sim', 'Food and Drink', 5)
# (16, 'Our Band Could Be Your Life: Scenes from the American Indie Underground, 1981-1991', Decimal('57.2500'), 'Sim', 'Food and Drink', 3)
# (17, 'Olio', Decimal('23.8800'), 'Sim', 'Food and Drink', 1)
# (18, 'Mesaerion: The Best Science Fiction Stories 1800-1849', Decimal('37.5900'), 'Sim', 'Food and Drink', 1)
# (19, 'Libertarianism for Beginners', Decimal('51.3300'), 'Sim', 'Food and Drink', 2)
# (20, "It's Only the Himalayas", Decimal('45.1700'), 'Sim', 'Food and Drink', 2)
# (21, 'In Her Wake', Decimal('12.8400'), 'Sim', 'Food and Drink', 1)
# (22, 'How Music Works', Decimal('37.3200'), 'Sim', 'Food and Drink', 2)
# (23, 'Foolproof Preserving: A Guide to Small Batch Jams, Jellies, Pickles, Condiments, and More: A Foolproof Guide to Making Small Batch Jams, Jellies, Pickles, Condiments, and More', Decimal('30.5200'), 'Sim', 'Food and Drink', 3)
# (24, 'Chase Me (Paris Nights #2)', Decimal('25.2700'), 'Sim', 'Food and Drink', 5)
# (25, 'Black Dust', Decimal('34.5300'), 'Sim', 'Food and Drink', 5)
# (26, 'Birdsong: A Story in Pictures', Decimal('54.6400'), 'Sim', 'Food and Drink', 3)
# (27, "America's Cradle of Quarterbacks: Western Pennsylvania's Football Factory from Johnny Unitas to Joe Montana", Decimal('22.5000'), 'Sim', 'Food and Drink', 3)
# (28, 'Aladdin and His Wonderful Lamp', Decimal('53.1300'), 'Sim', 'Food and Drink', 3)
# (29, 'Worlds Elsewhere: Journeys Around Shakespeareâ??s Globe', Decimal('40.3000'), 'Sim', 'Food and Drink', 5)
# (30, 'Wall and Piece', Decimal('44.1800'), 'Sim', 'Food and Drink', 4)
# (31, 'The Four Agreements: A Practical Guide to Personal Freedom', Decimal('17.6600'), 'Sim', 'Food and Drink', 5)
# (32, 'The Five Love Languages: How to Express Heartfelt Commitment to Your Mate', Decimal('31.0500'), 'Sim', 'Food and Drink', 3)
# (33, 'The Elephant Tree', Decimal('23.8200'), 'Sim', 'Food and Drink', 5)
# (34, 'The Bear and the Piano', Decimal('36.8900'), 'Sim', 'Food and Drink', 1)
# (35, "Sophie's World", Decimal('15.9400'), 'Sim', 'Food and Drink', 5)
# (36, 'Penny Maybe', Decimal('33.2900'), 'Sim', 'Food and Drink', 3)
# (37, 'Maude (1883-1993):She Grew Up with the country', Decimal('18.0200'), 'Sim', 'Food and Drink', 2)
# (38, 'In a Dark, Dark Wood', Decimal('19.6300'), 'Sim', 'Food and Drink', 1)
# (39, 'Behind Closed Doors', Decimal('52.2200'), 'Sim', 'Food and Drink', 4)
# (40, "You can't bury them all: Poems", Decimal('33.6300'), 'Sim', 'Food and Drink', 2)
# (41, 'Slow States of Collapse: Poems', Decimal('57.3100'), 'Sim', 'Food and Drink', 3)
# (42, 'Reasons to Stay Alive', Decimal('26.4100'), 'Sim', 'Food and Drink', 2)
# (43, 'Private Paris (Private #10)', Decimal('47.6100'), 'Sim', 'Food and Drink', 5)
# (44, '#HigherSelfie: Wake Up Your Life. Free Your Soul. Find Your Tribe.', Decimal('23.1100'), 'Sim', 'Food and Drink', 5)
# (45, 'Without Borders (Wanderlove #1)', Decimal('45.0700'), 'Sim', 'Food and Drink', 2)
# (46, 'When We Collided', Decimal('31.7700'), 'Sim', 'Food and Drink', 1)
# (47, 'We Love You, Charlie Freeman', Decimal('50.2700'), 'Sim', 'Food and Drink', 5)
# (48, 'Untitled Collection: Sabbath Poems 2014', Decimal('14.2700'), 'Sim', 'Food and Drink', 4)
# (49, 'Unseen City: The Majesty of Pigeons, the Discreet Charm of Snails & Other Wonders of the Urban Wilderness', Decimal('44.1800'), 'Sim', 'Food and Drink', 4)
# (50, 'Unicorn Tracks', Decimal('18.7800'), 'Sim', 'Food and Drink', 3)
# (51, 'Unbound: How Eight Technologies Made Us Human, Transformed Society, and Brought Our World to the Brink', Decimal('25.5200'), 'Sim', 'Food and Drink', 1)
# (52, 'Tsubasa: WoRLD CHRoNiCLE 2 (Tsubasa WoRLD CHRoNiCLE #2)', Decimal('16.2800'), 'Sim', 'Food and Drink', 1)
# (53, 'Throwing Rocks at the Google Bus: How Growth Became the Enemy of Prosperity', Decimal('31.1200'), 'Sim', 'Food and Drink', 3)
# (54, 'This One Summer', Decimal('19.4900'), 'Sim', 'Food and Drink', 4)
# (55, 'Thirst', Decimal('17.2700'), 'Sim', 'Food and Drink', 5)
# (56, 'The Torch Is Passed: A Harding Family Story', Decimal('19.0900'), 'Sim', 'Food and Drink', 1)
# (57, 'The Secret of Dreadwillow Carse', Decimal('56.1300'), 'Sim', 'Food and Drink', 1)
# (58, 'The Pioneer Woman Cooks: Dinnertime: Comfort Classics, Freezer Food, 16-Minute Meals, and Other Delicious Ways to Solve Supper!', Decimal('56.4100'), 'Sim', 'Food and Drink', 1)
# (59, 'The Past Never Ends', Decimal('56.5000'), 'Sim', 'Food and Drink', 4)
# (60, 'The Natural History of Us (The Fine Art of Pretending #2)', Decimal('45.2200'), 'Sim', 'Food and Drink', 3)
# (61, 'The Nameless City (The Nameless City #1)', Decimal('38.1600'), 'Sim', 'Food and Drink', 4)
# (62, 'The Murder That Never Was (Forensic Instincts #5)', Decimal('54.1100'), 'Sim', 'Food and Drink', 3)
# (63, "The Most Perfect Thing: Inside (and Outside) a Bird's Egg", Decimal('42.9600'), 'Sim', 'Food and Drink', 4)
# (64, 'The Mindfulness and Acceptance Workbook for Anxiety: A Guide to Breaking Free from Anxiety, Phobias, and Worry Using Acceptance and Commitment Therapy', Decimal('23.8900'), 'Sim', 'Food and Drink', 4)
# (65, 'The Life-Changing Magic of Tidying Up: The Japanese Art of Decluttering and Organizing', Decimal('16.7700'), 'Sim', 'Food and Drink', 3)
# (66, 'The Inefficiency Assassin: Time Management Tactics for Working Smarter, Not Longer', Decimal('20.5900'), 'Sim', 'Food and Drink', 5)
# (67, 'The Gutsy Girl: Escapades for Your Life of Epic Adventure', Decimal('37.1300'), 'Sim', 'Food and Drink', 1)
# (68, 'The Electric Pencil: Drawings from Inside State Hospital No. 3', Decimal('56.0600'), 'Sim', 'Food and Drink', 1)
# (69, 'The Death of Humanity: and the Case for Life', Decimal('58.1100'), 'Sim', 'Food and Drink', 4)
# (70, 'The Bulletproof Diet: Lose up to a Pound a Day, Reclaim Energy and Focus, Upgrade Your Life', Decimal('49.0500'), 'Sim', 'Food and Drink', 3)
# (71, 'The Art Forger', Decimal('40.7600'), 'Sim', 'Food and Drink', 3)
# (72, 'The Age of Genius: The Seventeenth Century and the Birth of the Modern Mind', Decimal('19.7300'), 'Sim', 'Food and Drink', 1)
# (73, "The Activist's Tao Te Ching: Ancient Advice for a Modern Revolution", Decimal('32.2400'), 'Sim', 'Food and Drink', 5)
# (74, 'Spark Joy: An Illustrated Master Class on the Art of Organizing and Tidying Up', Decimal('41.8300'), 'Sim', 'Food and Drink', 4)
# (75, 'Soul Reader', Decimal('39.5800'), 'Sim', 'Food and Drink', 2)
# (76, 'Security', Decimal('39.2500'), 'Sim', 'Food and Drink', 2)
# (77, 'Saga, Volume 6 (Saga (Collected Editions) #6)', Decimal('25.0200'), 'Sim', 'Food and Drink', 3)
# (78, 'Saga, Volume 5 (Saga (Collected Editions) #5)', Decimal('51.0400'), 'Sim', 'Food and Drink', 2)
# (79, 'Reskilling America: Learning to Labor in the Twenty-First Century', Decimal('19.8300'), 'Sim', 'Food and Drink', 2)
# (80, 'Rat Queens, Vol. 3: Demons (Rat Queens (Collected Editions) #11-15)', Decimal('50.4000'), 'Sim', 'Food and Drink', 3)
# (81, 'Princess Jellyfish 2-in-1 Omnibus, Vol. 01 (Princess Jellyfish 2-in-1 Omnibus #1)', Decimal('13.6100'), 'Sim', 'Food and Drink', 5)
# (82, 'Princess Between Worlds (Wide-Awake Princess #5)', Decimal('13.3400'), 'Sim', 'Food and Drink', 5)
# (83, 'Pop Gun War, Volume 1: Gift', Decimal('18.9700'), 'Sim', 'Food and Drink', 1)
# (84, 'Political Suicide: Missteps, Peccadilloes, Bad Calls, Backroom Hijinx, Sordid Pasts, Rotten Breaks, and Just Plain Dumb Mistakes in the Annals of American Politics', Decimal('36.2800'), 'Sim', 'Food and Drink', 2)
# (85, 'Patience', Decimal('10.1600'), 'Sim', 'Food and Drink', 3)
# (86, 'Outcast, Vol. 1: A Darkness Surrounds Him (Outcast #1)', Decimal('15.4400'), 'Sim', 'Food and Drink', 4)
# (87, 'orange: The Complete Collection 1 (orange: The Complete Collection #1)', Decimal('48.4100'), 'Sim', 'Food and Drink', 1)
# (88, 'Online Marketing for Busy Authors: A Step-By-Step Guide', Decimal('46.3500'), 'Sim', 'Food and Drink', 1)
# (89, 'On a Midnight Clear', Decimal('14.0700'), 'Sim', 'Food and Drink', 3)
# (90, 'Obsidian (Lux #1)', Decimal('14.8600'), 'Sim', 'Food and Drink', 2)
# (91, 'My Paris Kitchen: Recipes and Stories', Decimal('33.3700'), 'Sim', 'Food and Drink', 2)
# (92, 'Masks and Shadows', Decimal('56.4000'), 'Sim', 'Food and Drink', 2)
# (93, 'Mama Tried: Traditional Italian Cooking for the Screwed, Crude, Vegan, and Tattooed', Decimal('14.0200'), 'Sim', 'Food and Drink', 4)
# (94, 'Lumberjanes, Vol. 2: Friendship to the Max (Lumberjanes #5-8)', Decimal('46.9100'), 'Sim', 'Food and Drink', 2)
# (95, 'Lumberjanes, Vol. 1: Beware the Kitten Holy (Lumberjanes #1-4)', Decimal('45.6100'), 'Sim', 'Food and Drink', 3)
# (96, 'Lumberjanes Vol. 3: A Terrible Plan (Lumberjanes #9-12)', Decimal('19.9200'), 'Sim', 'Food and Drink', 2)
# (97, 'Layered: Baking, Building, and Styling Spectacular Cakes', Decimal('40.1100'), 'Sim', 'Food and Drink', 1)
# (98, 'Judo: Seven Steps to Black Belt (an Introductory Guide for Beginners)', Decimal('53.9000'), 'Sim', 'Food and Drink', 2)
# (99, 'Join', Decimal('35.6700'), 'Sim', 'Food and Drink', 5)
# (100, 'In the Country We Love: My Family Divided', Decimal('22.0000'), 'Sim', 'Food and Drink', 4)
# (101, 'Immunity: How Elie Metchnikoff Changed the Course of Modern Medicine', Decimal('57.3600'), 'Sim', 'Food and Drink', 5)
# (102, 'I Hate Fairyland, Vol. 1: Madly Ever After (I Hate Fairyland (Compilations) #1-5)', Decimal('29.1700'), 'Sim', 'Food and Drink', 2)
# (103, 'I am a Hero Omnibus Volume 1', Decimal('54.6300'), 'Sim', 'Food and Drink', 3)
# (104, 'How to Be Miserable: 40 Strategies You Already Use', Decimal('46.0300'), 'Sim', 'Food and Drink', 1)
# (105, 'Her Backup Boyfriend (The Sorensen Family #1)', Decimal('33.9700'), 'Sim', 'Food and Drink', 1)
# (106, 'Giant Days, Vol. 2 (Giant Days #5-8)', Decimal('22.1100'), 'Sim', 'Food and Drink', 2)
# (107, 'Forever and Forever: The Courtship of Henry Longfellow and Fanny Appleton', Decimal('29.6900'), 'Sim', 'Food and Drink', 3)
# (108, 'First and First (Five Boroughs #3)', Decimal('15.9700'), 'Sim', 'Food and Drink', 4)
# (109, 'Fifty Shades Darker (Fifty Shades #2)', Decimal('21.9600'), 'Sim', 'Food and Drink', 1)
# (110, 'Everydata: The Misinformation Hidden in the Little Data You Consume Every Day', Decimal('54.3500'), 'Sim', 'Food and Drink', 2)
# (111, "Don't Be a Jerk: And Other Practical Advice from Dogen, Japan's Greatest Zen Master", Decimal('37.9700'), 'Sim', 'Food and Drink', 2)
# (112, 'Danganronpa Volume 1', Decimal('51.9900'), 'Sim', 'Food and Drink', 4)
# (113, 'Crown of Midnight (Throne of Glass #2)', Decimal('43.2900'), 'Sim', 'Food and Drink', 3)
# (114, 'Codename Baboushka, Volume 1: The Conclave of Death', Decimal('36.7200'), 'Sim', 'Food and Drink', 4)
# (115, 'Camp Midnight', Decimal('17.0800'), 'Sim', 'Food and Drink', 4)
# (116, 'Call the Nurse: True Stories of a Country Nurse on a Scottish Isle', Decimal('29.1400'), 'Sim', 'Food and Drink', 5)
# (117, 'Burning', Decimal('28.8100'), 'Sim', 'Food and Drink', 3)
# (118, 'Bossypants', Decimal('49.4600'), 'Sim', 'Food and Drink', 2)
# (119, 'Bitch Planet, Vol. 1: Extraordinary Machine (Bitch Planet (Collected Editions))', Decimal('37.9200'), 'Sim', 'Food and Drink', 2)
# (120, 'Avatar: The Last Airbender: Smoke and Shadow, Part 3 (Smoke and Shadow #3)', Decimal('28.0900'), 'Sim', 'Food and Drink', 2)
# (121, 'Algorithms to Live By: The Computer Science of Human Decisions', Decimal('30.8100'), 'Sim', 'Food and Drink', 1)
# (122, 'A World of Flavor: Your Gluten Free Passport', Decimal('42.9500'), 'Sim', 'Food and Drink', 1)
# (123, 'A Piece of Sky, a Grain of Rice: A Memoir in Four Meditations', Decimal('56.7600'), 'Sim', 'Food and Drink', 5)
# (124, 'A Murder in Time', Decimal('16.6400'), 'Sim', 'Food and Drink', 1)
# (125, 'A Flight of Arrows (The Pathfinders #2)', Decimal('55.5300'), 'Sim', 'Food and Drink', 5)
# (126, 'A Fierce and Subtle Poison', Decimal('28.1300'), 'Sim', 'Food and Drink', 4)
# (127, 'A Court of Thorns and Roses (A Court of Thorns and Roses #1)', Decimal('52.3700'), 'Sim', 'Food and Drink', 1)
# (128, '(Un)Qualified: How God Uses Broken People to Do Big Things', Decimal('54.0000'), 'Sim', 'Food and Drink', 5)
# (129, 'You Are What You Love: The Spiritual Power of Habit', Decimal('21.8700'), 'Sim', 'Food and Drink', 4)
# (130, "William Shakespeare's Star Wars: Verily, A New Hope (William Shakespeare's Star Wars #4)", Decimal('43.3000'), 'Sim', 'Food and Drink', 4)
# (131, 'Tuesday Nights in 1980', Decimal('21.0400'), 'Sim', 'Food and Drink', 2)
# (132, 'Tracing Numbers on a Train', Decimal('41.6000'), 'Sim', 'Food and Drink', 3)
# (133, 'Throne of Glass (Throne of Glass #1)', Decimal('35.0700'), 'Sim', 'Food and Drink', 3)
# (134, 'Thomas Jefferson and the Tripoli Pirates: The Forgotten War That Changed American History', Decimal('59.6400'), 'Sim', 'Food and Drink', 1)
# (135, 'Thirteen Reasons Why', Decimal('52.7200'), 'Sim', 'Food and Drink', 1)
# (136, 'The White Cat and the Monk: A Retelling of the Poem â??Pangur BÃ¡nâ?\x9d', Decimal('58.0800'), 'Sim', 'Food and Drink', 4)
# (137, 'The Wedding Dress', Decimal('24.1200'), 'Sim', 'Food and Drink', 1)
# (138, 'The Vacationers', Decimal('42.1500'), 'Sim', 'Food and Drink', 4)
# (139, 'The Third Wave: An Entrepreneurâ??s Vision of the Future', Decimal('12.6100'), 'Sim', 'Food and Drink', 5)
# (140, 'The Stranger', Decimal('17.4400'), 'Sim', 'Food and Drink', 4)
# (141, 'The Shadow Hero (The Shadow Hero)', Decimal('33.1400'), 'Sim', 'Food and Drink', 1)
# (142, 'The Secret (The Secret #1)', Decimal('27.3700'), 'Sim', 'Food and Drink', 4)
# (143, 'The Regional Office Is Under Attack!', Decimal('51.3600'), 'Sim', 'Food and Drink', 5)
# (144, 'The Psychopath Test: A Journey Through the Madness Industry', Decimal('36.0000'), 'Sim', 'Food and Drink', 2)
# (145, 'The Project', Decimal('10.6500'), 'Sim', 'Food and Drink', 1)
# (146, 'The Power of Now: A Guide to Spiritual Enlightenment', Decimal('43.5400'), 'Sim', 'Food and Drink', 2)
# (147, "The Omnivore's Dilemma: A Natural History of Four Meals", Decimal('38.2100'), 'Sim', 'Food and Drink', 2)
# (148, 'The Nerdy Nummies Cookbook: Sweet Treats for the Geek in All of Us', Decimal('37.3400'), 'Sim', 'Food and Drink', 5)
# (149, 'The Murder of Roger Ackroyd (Hercule Poirot #4)', Decimal('44.1000'), 'Sim', 'Food and Drink', 4)
# (150, 'The Mistake (Off-Campus #2)', Decimal('43.2900'), 'Sim', 'Food and Drink', 3)
# (151, "The Matchmaker's Playbook (Wingmen Inc. #1)", Decimal('55.8500'), 'Sim', 'Food and Drink', 1)
# (152, 'The Love and Lemons Cookbook: An Apple-to-Zucchini Celebration of Impromptu Cooking', Decimal('37.6000'), 'Sim', 'Food and Drink', 2)
# (153, 'The Long Shadow of Small Ghosts: Murder and Memory in an American City', Decimal('10.9700'), 'Sim', 'Food and Drink', 1)
# (154, 'The Kite Runner', Decimal('41.8200'), 'Sim', 'Food and Drink', 4)
# (155, 'The House by the Lake', Decimal('36.9500'), 'Sim', 'Food and Drink', 1)
# (156, 'The Glittering Court (The Glittering Court #1)', Decimal('44.2800'), 'Sim', 'Food and Drink', 1)
# (157, 'The Girl on the Train', Decimal('55.0200'), 'Sim', 'Food and Drink', 2)
# (158, 'The Genius of Birds', Decimal('17.2400'), 'Sim', 'Food and Drink', 1)
# (159, 'The Emerald Mystery', Decimal('23.1500'), 'Sim', 'Food and Drink', 2)
# (160, 'The Cookies & Cups Cookbook: 125+ sweet & savory recipes reminding you to Always Eat Dessert First', Decimal('41.2500'), 'Sim', 'Food and Drink', 1)
# (161, "The Bridge to Consciousness: I'm Writing the Bridge Between Science and Our Old and New Beliefs.", Decimal('32.0000'), 'Sim', 'Food and Drink', 3)
# (162, "The Artist's Way: A Spiritual Path to Higher Creativity", Decimal('38.4900'), 'Sim', 'Food and Drink', 5)
# (163, 'The Art of War', Decimal('33.3400'), 'Sim', 'Food and Drink', 5)
# (164, 'The Argonauts', Decimal('10.9300'), 'Sim', 'Food and Drink', 2)
# (165, 'The 10% Entrepreneur: Live Your Startup Dream Without Quitting Your Day Job', Decimal('27.5500'), 'Sim', 'Food and Drink', 3)
# (166, 'Suddenly in Love (Lake Haven #1)', Decimal('55.9900'), 'Sim', 'Food and Drink', 2)
# (167, 'Something More Than This', Decimal('16.2400'), 'Sim', 'Food and Drink', 4)
# (168, 'Soft Apocalypse', Decimal('26.1200'), 'Sim', 'Food and Drink', 2)
# (169, "So You've Been Publicly Shamed", Decimal('12.2300'), 'Sim', 'Food and Drink', 2)
# (170, 'Shoe Dog: A Memoir by the Creator of NIKE', Decimal('23.9900'), 'Sim', 'Food and Drink', 2)
# (171, 'Shobu Samurai, Project Aryoku (#3)', Decimal('29.0600'), 'Sim', 'Food and Drink', 3)
# (172, 'Secrets and Lace (Fatal Hearts #1)', Decimal('20.2700'), 'Sim', 'Food and Drink', 1)
# (173, 'Scarlett Epstein Hates It Here', Decimal('43.5500'), 'Sim', 'Food and Drink', 5)
# (174, 'Romero and Juliet: A Tragic Tale of Love and Zombies', Decimal('36.9400'), 'Sim', 'Food and Drink', 1)
# (175, 'Redeeming Love', Decimal('20.4700'), 'Sim', 'Food and Drink', 5)
# (176, 'Poses for Artists Volume 1 - Dynamic and Sitting Poses: An Essential Reference for Figure Drawing and the Human Form', Decimal('41.0600'), 'Sim', 'Food and Drink', 1)
# (177, 'Poems That Make Grown Women Cry', Decimal('14.1900'), 'Sim', 'Food and Drink', 4)
# (178, 'Nightingale, Sing', Decimal('38.2800'), 'Sim', 'Food and Drink', 1)
# (179, 'Night Sky with Exit Wounds', Decimal('41.0500'), 'Sim', 'Food and Drink', 1)
# (180, 'Mrs. Houdini', Decimal('30.2500'), 'Sim', 'Food and Drink', 5)
# (181, 'Modern Romance', Decimal('28.2600'), 'Sim', 'Food and Drink', 5)
# (182, 'Miss Peregrineâ??s Home for Peculiar Children (Miss Peregrineâ??s Peculiar Children #1)', Decimal('10.7600'), 'Sim', 'Food and Drink', 1)
# (183, 'Louisa: The Extraordinary Life of Mrs. Adams', Decimal('16.8500'), 'Sim', 'Food and Drink', 2)
# (184, 'Little Red', Decimal('13.4700'), 'Sim', 'Food and Drink', 3)
# (185, 'Library of Souls (Miss Peregrineâ??s Peculiar Children #3)', Decimal('48.5600'), 'Sim', 'Food and Drink', 5)
# (186, 'Large Print Heart of the Pride', Decimal('19.1500'), 'Sim', 'Food and Drink', 2)
# (187, 'I Had a Nice Time And Other Lies...: How to find love & sh*t like that', Decimal('57.3600'), 'Sim', 'Food and Drink', 4)
# (188, 'Hollow City (Miss Peregrineâ??s Peculiar Children #2)', Decimal('42.9800'), 'Sim', 'Food and Drink', 1)
# (189, 'Grumbles', Decimal('22.1600'), 'Sim', 'Food and Drink', 2)
# (190, 'Full Moon over Noahâ??s Ark: An Odyssey to Mount Ararat and Beyond', Decimal('49.4300'), 'Sim', 'Food and Drink', 4)
# (191, 'Frostbite (Vampire Academy #2)', Decimal('29.9900'), 'Sim', 'Food and Drink', 5)
# (192, 'Follow You Home', Decimal('21.3600'), 'Sim', 'Food and Drink', 1)
# (193, 'First Steps for New Christians (Print Edition)', Decimal('29.0000'), 'Sim', 'Food and Drink', 1)
# (194, 'Finders Keepers (Bill Hodges Trilogy #2)', Decimal('53.5300'), 'Sim', 'Food and Drink', 5)
# (195, 'Fables, Vol. 1: Legends in Exile (Fables #1)', Decimal('41.6200'), 'Sim', 'Food and Drink', 4)
# (196, 'Eureka Trivia 6.0', Decimal('54.5900'), 'Sim', 'Food and Drink', 4)
# (197, 'Drive: The Surprising Truth About What Motivates Us', Decimal('34.9500'), 'Sim', 'Food and Drink', 4)
# (198, 'Done Rubbed Out (Reightman & Bailey #1)', Decimal('37.7200'), 'Sim', 'Food and Drink', 5)
# (199, 'Doing It Over (Most Likely To #1)', Decimal('35.6100'), 'Sim', 'Food and Drink', 3)
# (200, 'Deliciously Ella Every Day: Quick and Easy Recipes for Gluten-Free Snacks, Packed Lunches, and Simple Meals', Decimal('42.1600'), 'Sim', 'Food and Drink', 3)
# (201, 'Dark Notes', Decimal('19.1900'), 'Sim', 'Food and Drink', 5)
# (202, 'Daring Greatly: How the Courage to Be Vulnerable Transforms the Way We Live, Love, Parent, and Lead', Decimal('19.4300'), 'Sim', 'Food and Drink', 3)
# (203, 'Close to You', Decimal('49.4600'), 'Sim', 'Food and Drink', 4)
# (204, 'Chasing Heaven: What Dying Taught Me About Living', Decimal('37.8000'), 'Sim', 'Food and Drink', 2)
# (205, 'Big Magic: Creative Living Beyond Fear', Decimal('30.8000'), 'Sim', 'Food and Drink', 3)
# (206, 'Becoming Wise: An Inquiry into the Mystery and Art of Living', Decimal('27.4300'), 'Sim', 'Food and Drink', 2)
# (207, 'Beauty Restored (Riley Family Legacy Novellas #3)', Decimal('11.1100'), 'Sim', 'Food and Drink', 2)
# (208, 'Batman: The Long Halloween (Batman)', Decimal('36.5000'), 'Sim', 'Food and Drink', 2)
# (209, 'Batman: The Dark Knight Returns (Batman)', Decimal('15.3800'), 'Sim', 'Food and Drink', 5)
# (210, "Ayumi's Violin", Decimal('15.4800'), 'Sim', 'Food and Drink', 2)
# (211, 'Anonymous', Decimal('46.8200'), 'Sim', 'Food and Drink', 4)
# (212, 'Amy Meets the Saints and Sages', Decimal('18.4600'), 'Sim', 'Food and Drink', 3)
# (213, 'Amid the Chaos', Decimal('36.5800'), 'Sim', 'Food and Drink', 1)
# (214, 'Amatus', Decimal('50.5400'), 'Sim', 'Food and Drink', 5)
# (215, 'Agnostic: A Spirited Manifesto', Decimal('12.5100'), 'Sim', 'Food and Drink', 5)
# (216, 'Zealot: The Life and Times of Jesus of Nazareth', Decimal('24.7000'), 'Sim', 'Food and Drink', 3)
# (217, 'You (You #1)', Decimal('43.6100'), 'Sim', 'Food and Drink', 5)
# (218, 'Wonder Woman: Earth One, Volume One (Wonder Woman: Earth One #1)', Decimal('37.3400'), 'Sim', 'Food and Drink', 4)
# (219, 'Wild Swans', Decimal('14.3600'), 'Sim', 'Food and Drink', 2)
# (220, 'Why the Right Went Wrong: Conservatism--From Goldwater to the Tea Party and Beyond', Decimal('52.6500'), 'Sim', 'Food and Drink', 4)
# (221, 'Whole Lotta Creativity Going On: 60 Fun and Unusual Exercises to Awaken and Strengthen Your Creativity', Decimal('38.2000'), 'Sim', 'Food and Drink', 4)
# (222, "What's It Like in Space?: Stories from Astronauts Who've Been There", Decimal('19.6000'), 'Sim', 'Food and Drink', 2)
# (223, 'We Are Robin, Vol. 1: The Vigilante Business (We Are Robin #1)', Decimal('53.9000'), 'Sim', 'Food and Drink', 1)
# (224, "Walt Disney's Alice in Wonderland", Decimal('12.9600'), 'Sim', 'Food and Drink', 5)
# (225, 'V for Vendetta (V for Vendetta Complete)', Decimal('37.1000'), 'Sim', 'Food and Drink', 4)
# (226, 'Until Friday Night (The Field Party #1)', Decimal('46.3100'), 'Sim', 'Food and Drink', 2)
# (227, 'Unbroken: A World War II Story of Survival, Resilience, and Redemption', Decimal('45.9500'), 'Sim', 'Food and Drink', 2)
# (228, 'Twenty Yawns', Decimal('22.0800'), 'Sim', 'Food and Drink', 2)
# (229, 'Through the Woods', Decimal('25.3800'), 'Sim', 'Food and Drink', 2)
# (230, 'This Is Where It Ends', Decimal('27.1200'), 'Sim', 'Food and Drink', 2)
# (231, 'The Year of Magical Thinking', Decimal('43.0400'), 'Sim', 'Food and Drink', 2)
# (232, 'The Wright Brothers', Decimal('56.8000'), 'Sim', 'Food and Drink', 4)
# (233, "The White Queen (The Cousins' War #1)", Decimal('25.9100'), 'Sim', 'Food and Drink', 5)
# (234, "The Wedding Pact (The O'Malleys #2)", Decimal('32.6100'), 'Sim', 'Food and Drink', 3)
# (235, 'The Time Keeper', Decimal('27.8800'), 'Sim', 'Food and Drink', 5)
# (236, 'The Testament of Mary', Decimal('52.6700'), 'Sim', 'Food and Drink', 4)
# (237, 'The Star-Touched Queen', Decimal('46.0200'), 'Sim', 'Food and Drink', 5)
# (238, 'The Songs of the Gods', Decimal('44.4800'), 'Sim', 'Food and Drink', 5)
# (239, 'The Song of Achilles', Decimal('37.4000'), 'Sim', 'Food and Drink', 5)
# (240, 'The Rosie Project (Don Tillman #1)', Decimal('54.0400'), 'Sim', 'Food and Drink', 1)
# (241, 'The Power of Habit: Why We Do What We Do in Life and Business', Decimal('16.8800'), 'Sim', 'Food and Drink', 3)
# (242, 'The Marriage of Opposites', Decimal('28.0800'), 'Sim', 'Food and Drink', 4)
# (243, 'The Lucifer Effect: Understanding How Good People Turn Evil', Decimal('10.4000'), 'Sim', 'Food and Drink', 1)
# (244, 'The Long Haul (Diary of a Wimpy Kid #9)', Decimal('44.0700'), 'Sim', 'Food and Drink', 1)
# (245, 'The Loney', Decimal('23.4000'), 'Sim', 'Food and Drink', 1)
# (246, 'The Literature Book (Big Ideas Simply Explained)', Decimal('17.4300'), 'Sim', 'Food and Drink', 3)
# (247, 'The Last Mile (Amos Decker #2)', Decimal('54.2100'), 'Sim', 'Food and Drink', 2)
# (248, 'The Immortal Life of Henrietta Lacks', Decimal('40.6700'), 'Sim', 'Food and Drink', 2)
# (249, 'The Hidden Oracle (The Trials of Apollo #1)', Decimal('52.2600'), 'Sim', 'Food and Drink', 2)
# (250, 'The Help Yourself Cookbook for Kids: 60 Easy Plant-Based Recipes Kids Can Make to Stay Healthy and Save the Earth', Decimal('28.7700'), 'Sim', 'Food and Drink', 3)
# (251, 'The Guilty (Will Robie #4)', Decimal('13.8200'), 'Sim', 'Food and Drink', 2)
# (252, 'The First Hostage (J.B. Collins #2)', Decimal('25.8500'), 'Sim', 'Food and Drink', 3)
# (253, 'The Dovekeepers', Decimal('48.7800'), 'Sim', 'Food and Drink', 1)
# (254, 'The Darkest Lie', Decimal('35.3500'), 'Sim', 'Food and Drink', 5)
# (255, 'The Bane Chronicles (The Bane Chronicles #1-11)', Decimal('44.7300'), 'Sim', 'Food and Drink', 4)
# (256, 'The Bad-Ass Librarians of Timbuktu: And Their Race to Save the Worldâ??s Most Precious Manuscripts', Decimal('15.7700'), 'Sim', 'Food and Drink', 1)
# (257, 'The 14th Colony (Cotton Malone #11)', Decimal('39.2400'), 'Sim', 'Food and Drink', 1)
# (258, 'That Darkness (Gardiner and Renner #1)', Decimal('13.9200'), 'Sim', 'Food and Drink', 1)
# (259, 'Tastes Like Fear (DI Marnie Rome #3)', Decimal('10.6900'), 'Sim', 'Food and Drink', 1)
# (260, 'Take Me with You', Decimal('45.2100'), 'Sim', 'Food and Drink', 3)
# (261, 'Swell: A Year of Waves', Decimal('45.5800'), 'Sim', 'Food and Drink', 1)
# (262, 'Superman Vol. 1: Before Truth (Superman by Gene Luen Yang #1)', Decimal('11.8900'), 'Sim', 'Food and Drink', 5)
# (263, 'Still Life with Bread Crumbs', Decimal('26.4100'), 'Sim', 'Food and Drink', 3)
# (264, 'Steve Jobs', Decimal('39.5000'), 'Sim', 'Food and Drink', 5)
# (265, 'Sorting the Beef from the Bull: The Science of Food Fraud Forensics', Decimal('44.7400'), 'Sim', 'Food and Drink', 4)
# (266, 'Someone Like You (The Harrisons #2)', Decimal('52.7900'), 'Sim', 'Food and Drink', 5)
# (267, 'So Cute It Hurts!!, Vol. 6 (So Cute It Hurts!! #6)', Decimal('35.4300'), 'Sim', 'Food and Drink', 4)
# (268, 'Shtum', Decimal('55.8400'), 'Sim', 'Food and Drink', 4)
# (269, 'See America: A Celebration of Our National Parks & Treasured Sites', Decimal('48.8700'), 'Sim', 'Food and Drink', 3)
# (270, 'salt.', Decimal('46.7800'), 'Sim', 'Food and Drink', 4)
# (271, 'Robin War', Decimal('47.8200'), 'Sim', 'Food and Drink', 3)
# (272, 'Red Hood/Arsenal, Vol. 1: Open for Business (Red Hood/Arsenal #1)', Decimal('25.4800'), 'Sim', 'Food and Drink', 2)
# (273, 'Rain Fish', Decimal('23.5700'), 'Sim', 'Food and Drink', 3)
# (274, 'Quarter Life Poetry: Poems for the Young, Broke and Hangry', Decimal('50.8900'), 'Sim', 'Food and Drink', 5)
# (275, 'Pet Sematary', Decimal('10.5600'), 'Sim', 'Food and Drink', 3)
# (276, 'Overload: How to Unplug, Unwind, and Unleash Yourself from the Pressure of Stress', Decimal('52.1500'), 'Sim', 'Food and Drink', 3)
# (277, 'Once Was a Time', Decimal('18.2800'), 'Sim', 'Food and Drink', 2)
# (278, 'Old School (Diary of a Wimpy Kid #10)', Decimal('11.8300'), 'Sim', 'Food and Drink', 5)
# (279, 'No Dream Is Too High: Life Lessons From a Man Who Walked on the Moon', Decimal('21.9500'), 'Sim', 'Food and Drink', 2)
# (280, 'Naruto (3-in-1 Edition), Vol. 14: Includes Vols. 40, 41 & 42 (Naruto: Omnibus #14)', Decimal('38.3900'), 'Sim', 'Food and Drink', 2)
# (281, 'My Name Is Lucy Barton', Decimal('41.5600'), 'Sim', 'Food and Drink', 1)
# (282, 'My Mrs. Brown', Decimal('24.4800'), 'Sim', 'Food and Drink', 3)
# (283, 'My Kind of Crazy', Decimal('40.3600'), 'Sim', 'Food and Drink', 1)
# (284, 'Mr. Mercedes (Bill Hodges Trilogy #1)', Decimal('28.9000'), 'Sim', 'Food and Drink', 1)
# (285, 'More Than Music (Chasing the Dream #1)', Decimal('37.6100'), 'Sim', 'Food and Drink', 2)
# (286, 'Made to Stick: Why Some Ideas Survive and Others Die', Decimal('38.8500'), 'Sim', 'Food and Drink', 5)
# (287, 'Luis Paints the World', Decimal('53.9500'), 'Sim', 'Food and Drink', 3)
# (288, 'Luckiest Girl Alive', Decimal('49.8300'), 'Sim', 'Food and Drink', 3)
# (289, 'Lowriders to the Center of the Earth (Lowriders in Space #2)', Decimal('51.5100'), 'Sim', 'Food and Drink', 2)
# (290, 'Love Is a Mix Tape (Music #1)', Decimal('18.0300'), 'Sim', 'Food and Drink', 1)
# (291, 'Looking for Lovely: Collecting the Moments that Matter', Decimal('29.1400'), 'Sim', 'Food and Drink', 5)
# (292, 'Living Leadership by Insight: A Good Leader Achieves, a Great Leader Builds Monuments', Decimal('46.9100'), 'Sim', 'Food and Drink', 4)
# (293, 'Let It Out: A Journey Through Journaling', Decimal('26.7900'), 'Sim', 'Food and Drink', 5)
# (294, 'Lady Midnight (The Dark Artifices #1)', Decimal('16.2800'), 'Sim', 'Food and Drink', 5)
# (295, "It's All Easy: Healthy, Delicious Weeknight Meals in under 30 Minutes", Decimal('19.5500'), 'Sim', 'Food and Drink', 1)
# (296, 'Island of Dragons (Unwanteds #7)', Decimal('29.6500'), 'Sim', 'Food and Drink', 1)
# (297, "I Know What I'm Doing -- and Other Lies I Tell Myself: Dispatches from a Life Under Construction", Decimal('25.9800'), 'Sim', 'Food and Drink', 4)
# (298, 'I Am Pilgrim (Pilgrim #1)', Decimal('10.6000'), 'Sim', 'Food and Drink', 4)
# (299, 'Hyperbole and a Half: Unfortunate Situations, Flawed Coping Mechanisms, Mayhem, and Other Things That Happened', Decimal('14.7500'), 'Sim', 'Food and Drink', 5)
# (300, 'Hush, Hush (Hush, Hush #1)', Decimal('47.0200'), 'Sim', 'Food and Drink', 3)
# (301, 'Hold Your Breath (Search and Rescue #1)', Decimal('28.8200'), 'Sim', 'Food and Drink', 1)
# (302, 'Hamilton: The Revolution', Decimal('58.7900'), 'Sim', 'Food and Drink', 3)
# (303, 'Greek Mythic History', Decimal('10.2300'), 'Sim', 'Food and Drink', 5)
# (304, 'God: The Most Unpleasant Character in All Fiction', Decimal('30.0300'), 'Sim', 'Food and Drink', 5)
# (305, 'Glory over Everything: Beyond The Kitchen House', Decimal('45.8400'), 'Sim', 'Food and Drink', 3)
# (306, 'Feathers: Displays of Brilliant Plumage', Decimal('49.0500'), 'Sim', 'Food and Drink', 3)
# (307, 'Far & Away: Places on the Brink of Change: Seven Continents, Twenty-Five Years', Decimal('15.0600'), 'Sim', 'Food and Drink', 4)
# (308, 'Every Last Word', Decimal('46.4700'), 'Sim', 'Food and Drink', 3)
# (309, 'Eligible (The Austen Project #4)', Decimal('27.0900'), 'Sim', 'Food and Drink', 3)
# (310, 'El Deafo', Decimal('57.6200'), 'Sim', 'Food and Drink', 5)
# (311, 'Eight Hundred Grapes', Decimal('14.3900'), 'Sim', 'Food and Drink', 4)
# (312, 'Eaternity: More than 150 Deliciously Easy Vegan Recipes for a Long, Healthy, Satisfied, Joyful Life', Decimal('51.7500'), 'Sim', 'Food and Drink', 5)
# (313, 'Eat Fat, Get Thin', Decimal('54.0700'), 'Sim', 'Food and Drink', 2)
# (314, "Don't Get Caught", Decimal('55.3500'), 'Sim', 'Food and Drink', 1)
# (315, 'Doctor Sleep (The Shining #2)', Decimal('40.1200'), 'Sim', 'Food and Drink', 2)
# (316, 'Demigods & Magicians: Percy and Annabeth Meet the Kanes (Percy Jackson & Kane Chronicles Crossover #1-3)', Decimal('37.5100'), 'Sim', 'Food and Drink', 5)
# (317, 'Dear Mr. Knightley', Decimal('11.2100'), 'Sim', 'Food and Drink', 5)
# (318, 'Daily Fantasy Sports', Decimal('36.5800'), 'Sim', 'Food and Drink', 1)
# (319, 'Crazy Love: Overwhelmed by a Relentless God', Decimal('47.7200'), 'Sim', 'Food and Drink', 2)
# (320, 'Cometh the Hour (The Clifton Chronicles #6)', Decimal('25.0100'), 'Sim', 'Food and Drink', 3)
# (321, 'Code Name Verity (Code Name Verity #1)', Decimal('22.1300'), 'Sim', 'Food and Drink', 4)
# (322, 'Clockwork Angel (The Infernal Devices #1)', Decimal('44.1400'), 'Sim', 'Food and Drink', 1)
# (323, 'City of Glass (The Mortal Instruments #3)', Decimal('56.0200'), 'Sim', 'Food and Drink', 4)
# (324, 'City of Fallen Angels (The Mortal Instruments #4)', Decimal('11.2300'), 'Sim', 'Food and Drink', 4)
# (325, 'City of Bones (The Mortal Instruments #1)', Decimal('43.2800'), 'Sim', 'Food and Drink', 1)
# (326, 'City of Ashes (The Mortal Instruments #2)', Decimal('47.2700'), 'Sim', 'Food and Drink', 1)
# (327, 'Cell', Decimal('20.2900'), 'Sim', 'Food and Drink', 4)
# (328, 'Catching Jordan (Hundred Oaks)', Decimal('50.8300'), 'Sim', 'Food and Drink', 3)
# (329, 'Carry On, Warrior: Thoughts on Life Unarmed', Decimal('31.8500'), 'Sim', 'Food and Drink', 3)
# (330, 'Carrie', Decimal('46.2300'), 'Sim', 'Food and Drink', 2)
# (331, 'Buying In: The Secret Dialogue Between What We Buy and Who We Are', Decimal('37.8000'), 'Sim', 'Food and Drink', 4)
# (332, 'Brain on Fire: My Month of Madness', Decimal('49.3200'), 'Sim', 'Food and Drink', 5)
# (333, 'Batman: Europa', Decimal('32.0100'), 'Sim', 'Food and Drink', 2)
# (334, 'Barefoot Contessa Back to Basics', Decimal('28.0100'), 'Sim', 'Food and Drink', 1)
# (335, "Barefoot Contessa at Home: Everyday Recipes You'll Make Over and Over Again", Decimal('50.6200'), 'Sim', 'Food and Drink', 5)
# (336, 'Balloon Animals', Decimal('17.0300'), 'Sim', 'Food and Drink', 3)
# (337, 'Art Ops Vol. 1', Decimal('48.8000'), 'Sim', 'Food and Drink', 3)
# (338, 'Aristotle and Dante Discover the Secrets of the Universe (Aristotle and Dante Discover the Secrets of the Universe #1)', Decimal('58.1400'), 'Sim', 'Food and Drink', 4)
# (339, 'Angels Walking (Angels Walking #1)', Decimal('34.2000'), 'Sim', 'Food and Drink', 2)
# (340, 'Angels & Demons (Robert Langdon #1)', Decimal('51.4800'), 'Sim', 'Food and Drink', 3)
# (341, 'All the Light We Cannot See', Decimal('29.8700'), 'Sim', 'Food and Drink', 5)
# (342, 'Adulthood Is a Myth: A "Sarah\'s Scribbles" Collection', Decimal('10.9000'), 'Sim', 'Food and Drink', 2)
# (343, 'Abstract City', Decimal('56.3700'), 'Sim', 'Food and Drink', 5)
# (344, 'A Time of Torment (Charlie Parker #14)', Decimal('48.3500'), 'Sim', 'Food and Drink', 5)
# (345, 'A Study in Scarlet (Sherlock Holmes #1)', Decimal('16.7300'), 'Sim', 'Food and Drink', 2)
# (346, 'A Series of Catastrophes and Miracles: A True Story of Love, Science, and Cancer', Decimal('56.4800'), 'Sim', 'Food and Drink', 2)
# (347, "A People's History of the United States", Decimal('40.7900'), 'Sim', 'Food and Drink', 2)
# (348, 'A Man Called Ove', Decimal('39.7200'), 'Sim', 'Food and Drink', 1)
# (349, 'A Distant Mirror: The Calamitous 14th Century', Decimal('14.5800'), 'Sim', 'Food and Drink', 3)
# (350, 'A Brush of Wings (Angels Walking #3)', Decimal('55.5100'), 'Sim', 'Food and Drink', 1)
# (351, '1491: New Revelations of the Americas Before Columbus', Decimal('21.8000'), 'Sim', 'Food and Drink', 3)
# (352, 'The Three Searches, Meaning, and the Story', Decimal('13.3300'), 'Sim', 'Food and Drink', 3)
# (353, 'Searching for Meaning in Gailana', Decimal('38.7300'), 'Sim', 'Food and Drink', 1)
# (354, 'Rook', Decimal('37.8600'), 'Sim', 'Food and Drink', 4)
# (355, 'My Kitchen Year: 136 Recipes That Saved My Life', Decimal('11.5300'), 'Sim', 'Food and Drink', 2)
# (356, '13 Hours: The Inside Account of What Really Happened In Benghazi', Decimal('27.0600'), 'Sim', 'Food and Drink', 1)
# (357, "Will You Won't You Want Me?", Decimal('13.8600'), 'Sim', 'Food and Drink', 3)
# (358, 'Tipping Point for Planet Earth: How Close Are We to the Edge?', Decimal('37.5500'), 'Sim', 'Food and Drink', 1)
# (359, 'The Star-Touched Queen', Decimal('32.3000'), 'Sim', 'Food and Drink', 5)
# (360, 'The Silent Sister (Riley MacPherson #1)', Decimal('46.2900'), 'Sim', 'Food and Drink', 5)
# (361, 'The Midnight Watch: A Novel of the Titanic and the Californian', Decimal('26.2000'), 'Sim', 'Food and Drink', 1)
# (362, 'The Lonely City: Adventures in the Art of Being Alone', Decimal('33.2600'), 'Sim', 'Food and Drink', 2)
# (363, 'The Gray Rhino: How to Recognize and Act on the Obvious Dangers We Ignore', Decimal('59.1500'), 'Sim', 'Food and Drink', 4)
# (364, 'The Golden Condom: And Other Essays on Love Lost and Found', Decimal('39.4300'), 'Sim', 'Food and Drink', 1)
# (365, 'The Epidemic (The Program 0.6)', Decimal('14.4400'), 'Sim', 'Food and Drink', 5)
# (366, 'The Dinner Party', Decimal('56.5400'), 'Sim', 'Food and Drink', 2)
# (367, 'The Diary of a Young Girl', Decimal('59.9000'), 'Sim', 'Food and Drink', 3)
# (368, 'The Children', Decimal('11.8800'), 'Sim', 'Food and Drink', 3)
# (369, 'Stars Above (The Lunar Chronicles #4.5)', Decimal('48.0500'), 'Sim', 'Food and Drink', 2)
# (370, 'Snatched: How A Drug Queen Went Undercover for the DEA and Was Kidnapped By Colombian Guerillas', Decimal('21.2100'), 'Sim', 'Food and Drink', 3)
# (371, 'Raspberry Pi Electronics Projects for the Evil Genius', Decimal('49.6700'), 'Sim', 'Food and Drink', 4)
# (372, 'Quench Your Own Thirst: Business Lessons Learned Over a Beer or Two', Decimal('43.1400'), 'Sim', 'Food and Drink', 1)
# (373, 'Psycho: Sanitarium (Psycho #1.5)', Decimal('36.9700'), 'Sim', 'Food and Drink', 5)
# (374, 'Poisonous (Max Revere Novels #3)', Decimal('26.8000'), 'Sim', 'Food and Drink', 3)
# (375, 'One with You (Crossfire #5)', Decimal('15.7100'), 'Sim', 'Food and Drink', 4)
# (376, 'No Love Allowed (Dodge Cove #1)', Decimal('54.6500'), 'Sim', 'Food and Drink', 4)
# (377, 'Murder at the 42nd Street Library (Raymond Ambler #1)', Decimal('54.3600'), 'Sim', 'Food and Drink', 4)
# (378, 'Most Wanted', Decimal('35.2800'), 'Sim', 'Food and Drink', 3)
# (379, 'Love, Lies and Spies', Decimal('20.5500'), 'Sim', 'Food and Drink', 2)
# (380, 'How to Speak Golf: An Illustrated Guide to Links Lingo', Decimal('58.3200'), 'Sim', 'Food and Drink', 5)
# (381, 'Hide Away (Eve Duncan #20)', Decimal('11.8400'), 'Sim', 'Food and Drink', 1)
# (382, 'Furiously Happy: A Funny Book About Horrible Things', Decimal('41.4600'), 'Sim', 'Food and Drink', 4)
# (383, 'Everyday Italian: 125 Simple and Delicious Recipes', Decimal('20.1000'), 'Sim', 'Food and Drink', 5)
# (384, "Equal Is Unfair: America's Misguided Fight Against Income Inequality", Decimal('56.8600'), 'Sim', 'Food and Drink', 1)
# (385, 'Eleanor & Park', Decimal('56.5100'), 'Sim', 'Food and Drink', 5)
# (386, 'Dirty (Dive Bar #1)', Decimal('40.8300'), 'Sim', 'Food and Drink', 4)
# (387, 'Can You Keep a Secret? (Fear Street Relaunch #4)', Decimal('48.6400'), 'Sim', 'Food and Drink', 1)
# (388, 'Boar Island (Anna Pigeon #19)', Decimal('59.4800'), 'Sim', 'Food and Drink', 3)
# (389, 'A Paris Apartment', Decimal('39.0100'), 'Sim', 'Food and Drink', 4)
# (390, 'A la Mode: 120 Recipes in 60 Pairings: Pies, Tarts, Cakes, Crisps, and More Topped with Ice Cream, Gelato, Frozen Custard, and More', Decimal('38.7700'), 'Sim', 'Food and Drink', 1)
# (391, 'Troublemaker: Surviving Hollywood and Scientology', Decimal('48.3900'), 'Sim', 'Food and Drink', 2)
# (392, 'The Widow', Decimal('27.2600'), 'Sim', 'Food and Drink', 2)
# (393, 'The Sleep Revolution: Transforming Your Life, One Night at a Time', Decimal('11.6800'), 'Sim', 'Food and Drink', 4)
# (394, 'The Improbability of Love', Decimal('59.4500'), 'Sim', 'Food and Drink', 1)
# (395, 'The Art of Startup Fundraising', Decimal('21.0000'), 'Sim', 'Food and Drink', 3)
# (396, 'Take Me Home Tonight (Rock Star Romance #3)', Decimal('53.9800'), 'Sim', 'Food and Drink', 3)
# (397, 'Sleeping Giants (Themis Files #1)', Decimal('48.7400'), 'Sim', 'Food and Drink', 1)
# (398, 'Setting the World on Fire: The Brief, Astonishing Life of St. Catherine of Siena', Decimal('21.1500'), 'Sim', 'Food and Drink', 2)
# (399, 'Playing with Fire', Decimal('13.7100'), 'Sim', 'Food and Drink', 3)
# (400, 'Off the Hook (Fishing for Trouble #1)', Decimal('47.6700'), 'Sim', 'Food and Drink', 3)
# (401, 'Mothering Sunday', Decimal('13.3400'), 'Sim', 'Food and Drink', 2)
# (402, 'Mother, Can You Not?', Decimal('16.8900'), 'Sim', 'Food and Drink', 5)
# (403, 'M Train', Decimal('27.1800'), 'Sim', 'Food and Drink', 1)
# (404, 'Lilac Girls', Decimal('17.2800'), 'Sim', 'Food and Drink', 2)
# (405, 'Lies and Other Acts of Love', Decimal('45.1400'), 'Sim', 'Food and Drink', 1)
# (406, 'Lab Girl', Decimal('40.8500'), 'Sim', 'Food and Drink', 1)
# (407, 'Keep Me Posted', Decimal('20.4600'), 'Sim', 'Food and Drink', 4)
# (408, "It Didn't Start with You: How Inherited Family Trauma Shapes Who We Are and How to End the Cycle", Decimal('56.2700'), 'Sim', 'Food and Drink', 3)
# (409, 'Grey (Fifty Shades #4)', Decimal('48.4900'), 'Sim', 'Food and Drink', 4)
# (410, 'Exit, Pursued by a Bear', Decimal('51.3400'), 'Sim', 'Food and Drink', 4)
# (411, 'Daredevils', Decimal('16.3400'), 'Sim', 'Food and Drink', 3)
# (412, 'Cravings: Recipes for What You Want to Eat', Decimal('20.5000'), 'Sim', 'Food and Drink', 3)
# (413, 'Born for This: How to Find the Work You Were Meant to Do', Decimal('21.5900'), 'Sim', 'Food and Drink', 5)
# (414, 'Arena', Decimal('21.3600'), 'Sim', 'Food and Drink', 4)
# (415, 'Adultery', Decimal('20.8800'), 'Sim', 'Food and Drink', 5)
# (416, "A Mother's Reckoning: Living in the Aftermath of Tragedy", Decimal('19.5300'), 'Sim', 'Food and Drink', 3)
# (417, "A Gentleman's Position (Society of Gentlemen #3)", Decimal('14.7500'), 'Sim', 'Food and Drink', 5)
# (418, '11/22/63', Decimal('48.4800'), 'Sim', 'Food and Drink', 3)
# (419, '10% Happier: How I Tamed the Voice in My Head, Reduced Stress Without Losing My Edge, and Found Self-Help That Actually Works', Decimal('24.5700'), 'Sim', 'Food and Drink', 2)
# (420, '10-Day Green Smoothie Cleanse: Lose Up to 15 Pounds in 10 Days!', Decimal('49.7100'), 'Sim', 'Food and Drink', 5)
# (421, 'Without Shame', Decimal('48.2700'), 'Sim', 'Food and Drink', 5)
# (422, 'Watchmen', Decimal('58.0500'), 'Sim', 'Food and Drink', 4)
# (423, 'Unlimited Intuition Now', Decimal('58.8700'), 'Sim', 'Food and Drink', 4)
# (424, 'Underlying Notes', Decimal('11.8200'), 'Sim', 'Food and Drink', 2)
# (425, 'The Shack', Decimal('28.0300'), 'Sim', 'Food and Drink', 1)
# (426, 'The New Brand You: Your New Image Makes the Sale for You', Decimal('44.0500'), 'Sim', 'Food and Drink', 5)
# (427, 'The Moosewood Cookbook: Recipes from Moosewood Restaurant, Ithaca, New York', Decimal('12.3400'), 'Sim', 'Food and Drink', 4)
# (428, 'The Flowers Lied', Decimal('16.6800'), 'Sim', 'Food and Drink', 2)
# (429, 'The Fabric of the Cosmos: Space, Time, and the Texture of Reality', Decimal('55.9100'), 'Sim', 'Food and Drink', 1)
# (430, 'The Book of Mormon', Decimal('24.5700'), 'Sim', 'Food and Drink', 3)
# (431, 'The Art and Science of Low Carbohydrate Living', Decimal('52.9800'), 'Sim', 'Food and Drink', 5)
# (432, 'The Alien Club', Decimal('54.4000'), 'Sim', 'Food and Drink', 1)
# (433, 'Suzie Snowflake: One beautiful flake (a self-esteem story)', Decimal('54.8100'), 'Sim', 'Food and Drink', 5)
# (434, 'Nap-a-Roo', Decimal('25.0800'), 'Sim', 'Food and Drink', 1)
# (435, 'NaNo What Now? Finding your editing process, revising your NaNoWriMo book and building a writing career through publishing and beyond', Decimal('10.4100'), 'Sim', 'Food and Drink', 4)
# (436, 'Modern Day Fables', Decimal('47.4400'), 'Sim', 'Food and Drink', 2)
# (437, "If I Gave You God's Phone Number....: Searching for Spirituality in America", Decimal('20.9100'), 'Sim', 'Food and Drink', 1)
# (438, 'Fruits Basket, Vol. 9 (Fruits Basket #9)', Decimal('33.9500'), 'Sim', 'Food and Drink', 4)
# (439, 'Dress Your Family in Corduroy and Denim', Decimal('43.6800'), 'Sim', 'Food and Drink', 3)
# (440, "Don't Forget Steven", Decimal('33.2300'), 'Sim', 'Food and Drink', 1)
# (441, "Chernobyl 01:23:40: The Incredible True Story of the World's Worst Nuclear Disaster", Decimal('35.9200'), 'Sim', 'Food and Drink', 2)
# (442, 'Art and Fear: Observations on the Perils (and Rewards) of Artmaking', Decimal('48.6300'), 'Sim', 'Food and Drink', 4)
# (443, 'A Shard of Ice (The Black Symphony Saga #1)', Decimal('56.6300'), 'Sim', 'Food and Drink', 3)
# (444, "A Hero's Curse (The Unseen Chronicles #1)", Decimal('50.4900'), 'Sim', 'Food and Drink', 3)
# (445, '23 Degrees South: A Tropical Tale of Changing Whether...', Decimal('35.7900'), 'Sim', 'Food and Drink', 2)
# (446, 'Zero to One: Notes on Startups, or How to Build the Future', Decimal('34.0600'), 'Sim', 'Food and Drink', 3)
# (447, 'Why Not Me?', Decimal('17.7600'), 'Sim', 'Food and Drink', 1)
# (448, 'When Breath Becomes Air', Decimal('39.3600'), 'Sim', 'Food and Drink', 2)
# (449, 'Vagabonding: An Uncommon Guide to the Art of Long-Term World Travel', Decimal('36.9400'), 'Sim', 'Food and Drink', 2)
# (450, 'The Unlikely Pilgrimage of Harold Fry (Harold Fry #1)', Decimal('43.6200'), 'Sim', 'Food and Drink', 5)
# (451, 'The New Drawing on the Right Side of the Brain', Decimal('43.0200'), 'Sim', 'Food and Drink', 3)
# (452, "The Midnight Assassin: Panic, Scandal, and the Hunt for America's First Serial Killer", Decimal('28.4500'), 'Sim', 'Food and Drink', 4)
# (453, 'The Martian (The Martian #1)', Decimal('41.3900'), 'Sim', 'Food and Drink', 2)
# (454, 'The High Mountains of Portugal', Decimal('51.1500'), 'Sim', 'Food and Drink', 1)
# (455, 'The Grownup', Decimal('35.8800'), 'Sim', 'Food and Drink', 1)
# (456, "The E-Myth Revisited: Why Most Small Businesses Don't Work and What to Do About It", Decimal('36.9100'), 'Sim', 'Food and Drink', 1)
# (457, 'South of Sunshine', Decimal('28.9300'), 'Sim', 'Food and Drink', 1)
# (458, 'Smarter Faster Better: The Secrets of Being Productive in Life and Business', Decimal('38.8900'), 'Sim', 'Food and Drink', 5)
# (459, 'Silence in the Dark (Logan Point #4)', Decimal('58.3300'), 'Sim', 'Food and Drink', 3)
# (460, 'Shadows of the Past (Logan Point #1)', Decimal('39.6700'), 'Sim', 'Food and Drink', 5)
# (461, 'Roller Girl', Decimal('14.1000'), 'Sim', 'Food and Drink', 5)
# (462, 'Rising Strong', Decimal('21.8200'), 'Sim', 'Food and Drink', 3)
# (463, 'Proofs of God: Classical Arguments from Tertullian to Barth', Decimal('54.2100'), 'Sim', 'Food and Drink', 1)
# (464, 'Please Kill Me: The Uncensored Oral History of Punk', Decimal('31.1900'), 'Sim', 'Food and Drink', 4)
# (465, 'Out of Print: City Lights Spotlight No. 14', Decimal('53.6400'), 'Sim', 'Food and Drink', 5)
# (466, 'My Life Next Door (My Life Next Door )', Decimal('36.3900'), 'Sim', 'Food and Drink', 5)
# (467, "Miller's Valley", Decimal('58.5400'), 'Sim', 'Food and Drink', 2)
# (468, "Man's Search for Meaning", Decimal('29.4800'), 'Sim', 'Food and Drink', 3)
# (469, "Love That Boy: What Two Presidents, Eight Road Trips, and My Son Taught Me About a Parent's Expectations", Decimal('25.0600'), 'Sim', 'Food and Drink', 2)
# (470, 'Living Forward: A Proven Plan to Stop Drifting and Get the Life You Want', Decimal('12.5500'), 'Sim', 'Food and Drink', 3)
# (471, 'Les Fleurs du Mal', Decimal('29.0400'), 'Sim', 'Food and Drink', 5)
# (472, 'Left Behind (Left Behind #1)', Decimal('40.7200'), 'Sim', 'Food and Drink', 2)
# (473, "Kill 'Em and Leave: Searching for James Brown and the American Soul", Decimal('45.0500'), 'Sim', 'Food and Drink', 5)
# (474, 'Kierkegaard: A Christian Missionary to Christians', Decimal('47.1300'), 'Sim', 'Food and Drink', 1)
# (475, 'John Vassos: Industrial Design for Modern Life', Decimal('20.2200'), 'Sim', 'Food and Drink', 4)
# (476, "I'll Give You the Sun", Decimal('56.4800'), 'Sim', 'Food and Drink', 1)
# (477, 'I Will Find You', Decimal('44.2100'), 'Sim', 'Food and Drink', 1)
# (478, 'Hystopia: A Novel', Decimal('21.9600'), 'Sim', 'Food and Drink', 4)
# (479, 'Howl and Other Poems', Decimal('40.4500'), 'Sim', 'Food and Drink', 2)
# (480, 'History of Beauty', Decimal('10.2900'), 'Sim', 'Food and Drink', 4)
# (481, "Heaven is for Real: A Little Boy's Astounding Story of His Trip to Heaven and Back", Decimal('52.8600'), 'Sim', 'Food and Drink', 2)
# (482, 'Future Shock (Future Shock #1)', Decimal('55.6500'), 'Sim', 'Food and Drink', 5)
# (483, "Ender's Game (The Ender Quintet #1)", Decimal('43.6400'), 'Sim', 'Food and Drink', 1)
# ...
# (824, 'Into the Wild', Decimal('56.7000'), 'Sim', 'Food and Drink', 5)
# (825, 'Inferno (Robert Langdon #4)', Decimal('41.0000'), 'Sim', 'Food and Drink', 5)
# (826, "In the Garden of Beasts: Love, Terror, and an American Family in Hitler's Berlin", Decimal('28.8500'), 'Sim', 'Food and Drink', 3)
# (827, 'If I Run (If I Run #1)', Decimal('49.9700'), 'Sim', 'Food and Drink', 4)
# (828, "I've Got Your Number", Decimal('19.6900'), 'Sim', 'Food and Drink', 1)
# (829, 'I Am Malala: The Girl Who Stood Up for Education and Was Shot by the Taliban', Decimal('28.8800'), 'Sim', 'Food and Drink', 2)
# (830, 'Hungry Girl Clean & Hungry: Easy All-Natural Recipes for Healthy Eating in the Real World', Decimal('33.1400'), 'Sim', 'Food and Drink', 3)
# (831, 'House of Lost Worlds: Dinosaurs, Dynasties, and the Story of Life on Earth', Decimal('43.7000'), 'Sim', 'Food and Drink', 2)
# (832, 'House of Leaves', Decimal('54.8900'), 'Sim', 'Food and Drink', 1)
# (833, 'Horrible Bear!', Decimal('37.5200'), 'Sim', 'Food and Drink', 2)
# (834, 'Holidays on Ice', Decimal('51.0700'), 'Sim', 'Food and Drink', 2)
# (835, 'Heir to the Sky', Decimal('44.0700'), 'Sim', 'Food and Drink', 4)
# (836, 'Green Eggs and Ham (Beginner Books B-16)', Decimal('10.7900'), 'Sim', 'Food and Drink', 4)
# (837, 'Grayson, Vol 3: Nemesis (Grayson #3)', Decimal('42.7200'), 'Sim', 'Food and Drink', 1)
# (838, 'Gratitude', Decimal('26.6600'), 'Sim', 'Food and Drink', 5)
# (839, 'Gone Girl', Decimal('37.6000'), 'Sim', 'Food and Drink', 5)
# (840, 'Golden (Heart of Dread #3)', Decimal('42.2100'), 'Sim', 'Food and Drink', 4)
# (841, 'Girl in the Blue Coat', Decimal('46.8300'), 'Sim', 'Food and Drink', 2)
# (842, 'Fruits Basket, Vol. 3 (Fruits Basket #3)', Decimal('45.1700'), 'Sim', 'Food and Drink', 2)
# (843, 'Friday Night Lights: A Town, a Team, and a Dream', Decimal('51.2200'), 'Sim', 'Food and Drink', 3)
# (844, 'Fire Bound (Sea Haven/Sisters of the Heart #5)', Decimal('21.2800'), 'Sim', 'Food and Drink', 4)
# (845, 'Fifty Shades Freed (Fifty Shades #3)', Decimal('15.3600'), 'Sim', 'Food and Drink', 5)
# (846, 'Fellside', Decimal('38.6200'), 'Sim', 'Food and Drink', 1)
# (847, 'Extreme Prey (Lucas Davenport #26)', Decimal('25.4000'), 'Sim', 'Food and Drink', 3)
# (848, 'Eragon (The Inheritance Cycle #1)', Decimal('43.8700'), 'Sim', 'Food and Drink', 3)
# (849, 'Eclipse (Twilight #3)', Decimal('18.7400'), 'Sim', 'Food and Drink', 1)
# (850, 'Dune (Dune #1)', Decimal('54.8600'), 'Sim', 'Food and Drink', 1)
# (851, 'Dracula', Decimal('52.6200'), 'Sim', 'Food and Drink', 3)
# (852, 'Do Androids Dream of Electric Sheep? (Blade Runner #1)', Decimal('51.4800'), 'Sim', 'Food and Drink', 1)
# (853, 'Disrupted: My Misadventure in the Start-Up Bubble', Decimal('15.2800'), 'Sim', 'Food and Drink', 5)
# (854, 'Dead Wake: The Last Crossing of the Lusitania', Decimal('39.2400'), 'Sim', 'Food and Drink', 5)
# (855, 'David and Goliath: Underdogs, Misfits, and the Art of Battling Giants', Decimal('17.8100'), 'Sim', 'Food and Drink', 1)
# (856, 'Darkfever (Fever #1)', Decimal('56.0200'), 'Sim', 'Food and Drink', 1)
# (857, 'Dark Places', Decimal('23.9000'), 'Sim', 'Food and Drink', 5)
# (858, 'Crazy Rich Asians (Crazy Rich Asians #1)', Decimal('49.1300'), 'Sim', 'Food and Drink', 5)
# (859, 'Counting Thyme', Decimal('10.6200'), 'Sim', 'Food and Drink', 1)
# (860, 'Cosmos', Decimal('36.1700'), 'Sim', 'Food and Drink', 2)
# (861, 'Civilization and Its Discontents', Decimal('59.9500'), 'Sim', 'Food and Drink', 2)
# (862, 'Cinder (The Lunar Chronicles #1)', Decimal('26.0900'), 'Sim', 'Food and Drink', 1)
# (863, "Catastrophic Happiness: Finding Joy in Childhood's Messy Years", Decimal('37.3500'), 'Sim', 'Food and Drink', 2)
# (864, 'Career of Evil (Cormoran Strike #3)', Decimal('24.7200'), 'Sim', 'Food and Drink', 2)
# (865, 'Breaking Dawn (Twilight #4)', Decimal('35.2800'), 'Sim', 'Food and Drink', 5)
# (866, 'Brave Enough', Decimal('51.3200'), 'Sim', 'Food and Drink', 5)
# (867, 'Boy Meets Boy', Decimal('21.1200'), 'Sim', 'Food and Drink', 3)
# (868, 'Born to Run: A Hidden Tribe, Superathletes, and the Greatest Race the World Has Never Seen', Decimal('27.3500'), 'Sim', 'Food and Drink', 2)
# (869, 'Blink: The Power of Thinking Without Thinking', Decimal('21.7400'), 'Sim', 'Food and Drink', 5)
# (870, 'Black Flags: The Rise of ISIS', Decimal('40.8700'), 'Sim', 'Food and Drink', 1)
# (871, 'Black Butler, Vol. 1 (Black Butler #1)', Decimal('49.3100'), 'Sim', 'Food and Drink', 1)
# (872, 'Big Little Lies', Decimal('22.1100'), 'Sim', 'Food and Drink', 1)
# (873, 'Between Shades of Gray', Decimal('20.7900'), 'Sim', 'Food and Drink', 5)
# (874, "Best of My Love (Fool's Gold #20)", Decimal('27.4100'), 'Sim', 'Food and Drink', 2)
# (875, 'Beowulf', Decimal('38.3500'), 'Sim', 'Food and Drink', 2)
# (876, 'Beautiful Creatures (Caster Chronicles #1)', Decimal('21.5500'), 'Sim', 'Food and Drink', 5)
# (877, 'Awkward', Decimal('38.0200'), 'Sim', 'Food and Drink', 2)
# (878, 'Ash', Decimal('22.0600'), 'Sim', 'Food and Drink', 4)
# (879, 'Are We There Yet?', Decimal('10.6600'), 'Sim', 'Food and Drink', 3)
# (880, 'Are We Smart Enough to Know How Smart Animals Are?', Decimal('56.5800'), 'Sim', 'Food and Drink', 1)
# (881, 'Annie on My Mind', Decimal('36.8300'), 'Sim', 'Food and Drink', 5)
# (882, 'And Then There Were None', Decimal('35.0100'), 'Sim', 'Food and Drink', 2)
# (883, 'A Walk in the Woods: Rediscovering America on the Appalachian Trail', Decimal('30.4800'), 'Sim', 'Food and Drink', 4)
# (884, 'A Visit from the Goon Squad', Decimal('14.0800'), 'Sim', 'Food and Drink', 5)
# (885, 'A Storm of Swords (A Song of Ice and Fire #3)', Decimal('31.2200'), 'Sim', 'Food and Drink', 2)
# (886, 'A Heartbreaking Work of Staggering Genius', Decimal('54.2900'), 'Sim', 'Food and Drink', 5)
# (887, '8 Keys to Mental Health Through Exercise', Decimal('31.0400'), 'Sim', 'Food and Drink', 1)
# (888, '#GIRLBOSS', Decimal('50.9600'), 'Sim', 'Food and Drink', 1)
# (889, 'The Suffragettes (Little Black Classics, #96)', Decimal('11.8900'), 'Sim', 'Food and Drink', 2)
# (890, 'The Sense of an Ending', Decimal('31.3800'), 'Sim', 'Food and Drink', 3)
# (891, "The Sandman, Vol. 2: The Doll's House (The Sandman (volumes) #2)", Decimal('54.8100'), 'Sim', 'Food and Drink', 1)
# (892, 'The Course of Love', Decimal('16.7800'), 'Sim', 'Food and Drink', 3)
# (893, 'Sugar Rush (Offensive Line #2)', Decimal('24.4200'), 'Sim', 'Food and Drink', 1)
# (894, 'Saga, Volume 2 (Saga (Collected Editions) #2)', Decimal('11.7500'), 'Sim', 'Food and Drink', 3)
# (895, 'Run, Spot, Run: The Ethics of Keeping Pets', Decimal('20.0200'), 'Sim', 'Food and Drink', 1)
# (896, 'New Moon (Twilight #2)', Decimal('12.8600'), 'Sim', 'Food and Drink', 4)
# (897, 'Life', Decimal('31.5800'), 'Sim', 'Food and Drink', 5)
# (898, "Kindle Paperwhite User's Guide", Decimal('34.0000'), 'Sim', 'Food and Drink', 3)
# (899, 'H is for Hawk', Decimal('57.4200'), 'Sim', 'Food and Drink', 5)
# (900, 'Girl Online On Tour (Girl Online #2)', Decimal('53.4700'), 'Sim', 'Food and Drink', 1)
# (901, 'Fruits Basket, Vol. 2 (Fruits Basket #2)', Decimal('11.6400'), 'Sim', 'Food and Drink', 5)
# (902, 'Diary of a Minecraft Zombie Book 1: A Scare of a Dare (An Unofficial Minecraft Book)', Decimal('52.8800'), 'Sim', 'Food and Drink', 4)
# (903, 'Y: The Last Man, Vol. 1: Unmanned (Y: The Last Man #1)', Decimal('18.5100'), 'Sim', 'Food and Drink', 4)
# (904, 'While You Were Mine', Decimal('41.3200'), 'Sim', 'Food and Drink', 5)
# (905, 'Where Lightning Strikes (Bleeding Stars #3)', Decimal('39.7700'), 'Sim', 'Food and Drink', 3)
# (906, "When I'm Gone", Decimal('51.9600'), 'Sim', 'Food and Drink', 3)
# (907, 'Ways of Seeing', Decimal('39.5100'), 'Sim', 'Food and Drink', 5)
# (908, 'Vampire Knight, Vol. 1 (Vampire Knight #1)', Decimal('15.4000'), 'Sim', 'Food and Drink', 1)
# (909, 'Vampire Girl (Vampire Girl #1)', Decimal('53.8200'), 'Sim', 'Food and Drink', 2)
# (910, 'Twenty Love Poems and a Song of Despair', Decimal('30.9500'), 'Sim', 'Food and Drink', 4)
# (911, 'Travels with Charley: In Search of America', Decimal('57.8200'), 'Sim', 'Food and Drink', 5)
# (912, 'Three Wishes (River of Time: California #1)', Decimal('44.1800'), 'Sim', 'Food and Drink', 2)
# (913, 'This One Moment (Pushing Limits #1)', Decimal('48.7100'), 'Sim', 'Food and Drink', 1)
# (914, 'The Zombie Room', Decimal('19.6900'), 'Sim', 'Food and Drink', 5)
# (915, 'The Wicked + The Divine, Vol. 1: The Faust Act (The Wicked + The Divine)', Decimal('36.5200'), 'Sim', 'Food and Drink', 2)
# (916, 'The Tumor', Decimal('41.5600'), 'Sim', 'Food and Drink', 5)
# (917, 'The Story of Hong Gildong', Decimal('43.1900'), 'Sim', 'Food and Drink', 4)
# (918, 'The Silent Wife', Decimal('12.3400'), 'Sim', 'Food and Drink', 5)
# (919, 'The Silent Twin (Detective Jennifer Knight #3)', Decimal('36.2500'), 'Sim', 'Food and Drink', 3)
# (920, 'The Selfish Gene', Decimal('29.4500'), 'Sim', 'Food and Drink', 1)
# (921, 'The Secret Healer', Decimal('34.5600'), 'Sim', 'Food and Drink', 3)
# (922, 'The Sandman, Vol. 1: Preludes and Nocturnes (The Sandman (volumes) #1)', Decimal('54.1200'), 'Sim', 'Food and Drink', 3)
# (923, 'The Republic', Decimal('33.7800'), 'Sim', 'Food and Drink', 3)
# (924, 'The Odyssey', Decimal('29.6400'), 'Sim', 'Food and Drink', 3)
# (925, "The No. 1 Ladies' Detective Agency (No. 1 Ladies' Detective Agency #1)", Decimal('57.7000'), 'Sim', 'Food and Drink', 4)
# (926, 'The Nicomachean Ethics', Decimal('36.3400'), 'Sim', 'Food and Drink', 1)
# (927, 'The Name of the Wind (The Kingkiller Chronicle #1)', Decimal('50.5900'), 'Sim', 'Food and Drink', 3)
# (928, 'The Mirror & the Maze (The Wrath and the Dawn #1.5)', Decimal('29.3800'), 'Sim', 'Food and Drink', 1)
# (929, 'The Little Prince', Decimal('45.4200'), 'Sim', 'Food and Drink', 2)
# (930, 'The Light of the Fireflies', Decimal('54.4300'), 'Sim', 'Food and Drink', 1)
# (931, 'The Last Girl (The Dominion Trilogy #1)', Decimal('36.2600'), 'Sim', 'Food and Drink', 2)
# (932, 'The Iliad', Decimal('16.1600'), 'Sim', 'Food and Drink', 1)
# (933, 'The Hook Up (Game On #1)', Decimal('36.2900'), 'Sim', 'Food and Drink', 5)
# (934, 'The Haters', Decimal('27.8900'), 'Sim', 'Food and Drink', 5)
# (935, 'The Girl You Lost', Decimal('12.2900'), 'Sim', 'Food and Drink', 5)
# (936, 'The Girl In The Ice (DCI Erika Foster #1)', Decimal('15.8500'), 'Sim', 'Food and Drink', 3)
# (937, 'The End of the Jesus Era (An Investigation #1)', Decimal('14.4000'), 'Sim', 'Food and Drink', 1)
# (938, 'The Edge of Reason (Bridget Jones #2)', Decimal('19.1800'), 'Sim', 'Food and Drink', 4)
# (939, 'The Complete Maus (Maus #1-2)', Decimal('10.6400'), 'Sim', 'Food and Drink', 3)
# (940, 'The Communist Manifesto', Decimal('14.7600'), 'Sim', 'Food and Drink', 3)
# (941, 'The Bhagavad Gita', Decimal('57.4900'), 'Sim', 'Food and Drink', 3)
# (942, 'The Bette Davis Club', Decimal('30.6600'), 'Sim', 'Food and Drink', 3)
# (943, 'The Art of Not Breathing', Decimal('40.8300'), 'Sim', 'Food and Drink', 4)
# (944, 'Taking Shots (Assassins #1)', Decimal('18.8800'), 'Sim', 'Food and Drink', 2)
# (945, 'Starlark', Decimal('25.8300'), 'Sim', 'Food and Drink', 3)
# (946, 'Skip Beat!, Vol. 01 (Skip Beat! #1)', Decimal('42.1200'), 'Sim', 'Food and Drink', 3)
# (947, 'Sister Sable (The Mad Queen #1)', Decimal('13.3300'), 'Sim', 'Food and Drink', 3)
# (948, 'Shatter Me (Shatter Me #1)', Decimal('42.4000'), 'Sim', 'Food and Drink', 1)
# (949, 'Shameless', Decimal('58.3500'), 'Sim', 'Food and Drink', 3)
# (950, 'Shadow Rites (Jane Yellowrock #10)', Decimal('21.7200'), 'Sim', 'Food and Drink', 4)
# (951, 'Settling the Score (The Summer Games #1)', Decimal('44.9100'), 'Sim', 'Food and Drink', 2)
# (952, 'Sense and Sensibility', Decimal('37.4600'), 'Sim', 'Food and Drink', 1)
# (953, 'Saga, Volume 1 (Saga (Collected Editions) #1)', Decimal('28.4800'), 'Sim', 'Food and Drink', 1)
# (954, 'Rhythm, Chord & Malykhin', Decimal('28.3400'), 'Sim', 'Food and Drink', 2)
# (955, 'Rat Queens, Vol. 1: Sass & Sorcery (Rat Queens (Collected Editions) #1-5)', Decimal('46.9600'), 'Sim', 'Food and Drink', 5)
# (956, 'Paradise Lost (Paradise #1)', Decimal('24.9600'), 'Sim', 'Food and Drink', 1)
# (957, 'Paper Girls, Vol. 1 (Paper Girls #1-5)', Decimal('21.7100'), 'Sim', 'Food and Drink', 4)
# (958, 'Ouran High School Host Club, Vol. 1 (Ouran High School Host Club #1)', Decimal('29.8700'), 'Sim', 'Food and Drink', 3)
# (959, 'Origins (Alphas 0.5)', Decimal('28.9900'), 'Sim', 'Food and Drink', 1)
# (960, 'One Second (Seven #7)', Decimal('52.9400'), 'Sim', 'Food and Drink', 2)
# (961, 'On the Road (Duluoz Legend)', Decimal('32.3600'), 'Sim', 'Food and Drink', 3)
# (962, "Old Records Never Die: One Man's Quest for His Vinyl and His Past", Decimal('55.6600'), 'Sim', 'Food and Drink', 2)
# (963, 'Off Sides (Off #1)', Decimal('39.4500'), 'Sim', 'Food and Drink', 5)
# (964, 'Of Mice and Men', Decimal('47.1100'), 'Sim', 'Food and Drink', 2)
# (965, 'Myriad (Prentor #1)', Decimal('58.7500'), 'Sim', 'Food and Drink', 4)
# (966, 'My Perfect Mistake (Over the Top #1)', Decimal('38.9200'), 'Sim', 'Food and Drink', 2)
# (967, 'Ms. Marvel, Vol. 1: No Normal (Ms. Marvel (2014-2015) #1)', Decimal('39.3900'), 'Sim', 'Food and Drink', 4)
# (968, 'Meditations', Decimal('25.8900'), 'Sim', 'Food and Drink', 2)
# (969, 'Matilda', Decimal('28.3400'), 'Sim', 'Food and Drink', 1)
# (970, 'Lost Among the Living', Decimal('27.7000'), 'Sim', 'Food and Drink', 4)
# (971, 'Lord of the Flies', Decimal('24.8900'), 'Sim', 'Food and Drink', 3)
# (972, 'Listen to Me (Fusion #1)', Decimal('58.9900'), 'Sim', 'Food and Drink', 3)
# (973, 'Kitchens of the Great Midwest', Decimal('57.2000'), 'Sim', 'Food and Drink', 5)
# (974, 'Jane Eyre', Decimal('38.4300'), 'Sim', 'Food and Drink', 5)
# (975, 'Imperfect Harmony', Decimal('34.7400'), 'Sim', 'Food and Drink', 4)
# (976, 'Icing (Aces Hockey #2)', Decimal('40.4400'), 'Sim', 'Food and Drink', 4)
# (977, 'Hawkeye, Vol. 1: My Life as a Weapon (Hawkeye #1)', Decimal('45.2400'), 'Sim', 'Food and Drink', 3)
# (978, "Having the Barbarian's Baby (Ice Planet Barbarians #7.5)", Decimal('34.9600'), 'Sim', 'Food and Drink', 4)
# (979, 'Giant Days, Vol. 1 (Giant Days #1-4)', Decimal('56.7600'), 'Sim', 'Food and Drink', 4)
# (980, 'Fruits Basket, Vol. 1 (Fruits Basket #1)', Decimal('40.2800'), 'Sim', 'Food and Drink', 5)
# (981, 'Frankenstein', Decimal('38.0000'), 'Sim', 'Food and Drink', 2)
# (982, 'Forever Rockers (The Rocker #12)', Decimal('28.8000'), 'Sim', 'Food and Drink', 3)
# (983, 'Fighting Fate (Fighting #6)', Decimal('39.2400'), 'Sim', 'Food and Drink', 3)
# (984, 'Emma', Decimal('32.9300'), 'Sim', 'Food and Drink', 2)
# (985, 'Eat, Pray, Love', Decimal('51.3200'), 'Sim', 'Food and Drink', 3)
# (986, 'Deep Under (Walker Security #1)', Decimal('47.0900'), 'Sim', 'Food and Drink', 5)
# (987, "Choosing Our Religion: The Spiritual Lives of America's Nones", Decimal('28.4200'), 'Sim', 'Food and Drink', 4)
# (988, 'Charlie and the Chocolate Factory (Charlie Bucket #1)', Decimal('22.8500'), 'Sim', 'Food and Drink', 3)
# (989, "Charity's Cross (Charles Towne Belles #4)", Decimal('41.2400'), 'Sim', 'Food and Drink', 1)
# (990, 'Bright Lines', Decimal('39.0700'), 'Sim', 'Food and Drink', 5)
# (991, "Bridget Jones's Diary (Bridget Jones #1)", Decimal('29.8200'), 'Sim', 'Food and Drink', 1)
# (992, 'Bounty (Colorado Mountain #7)', Decimal('37.2600'), 'Sim', 'Food and Drink', 4)
# (993, 'Blood Defense (Samantha Brinkman #1)', Decimal('20.3000'), 'Sim', 'Food and Drink', 3)
# (994, 'Bleach, Vol. 1: Strawberry and the Soul Reapers (Bleach #1)', Decimal('34.6500'), 'Sim', 'Food and Drink', 5)
# (995, 'Beyond Good and Evil', Decimal('43.3800'), 'Sim', 'Food and Drink', 1)
# (996, "Alice in Wonderland (Alice's Adventures in Wonderland #1)", Decimal('55.5300'), 'Sim', 'Food and Drink', 1)
# (997, 'Ajin: Demi-Human, Volume 1 (Ajin: Demi-Human #1)', Decimal('57.0600'), 'Sim', 'Food and Drink', 4)
# (998, "A Spy's Devotion (The Regency Spies of London #1)", Decimal('16.9700'), 'Sim', 'Food and Drink', 5)
# (999, "1st to Die (Women's Murder Club #1)", Decimal('53.9800'), 'Sim', 'Food and Drink', 1)
# (1000, '1,000 Places to See Before You Die', Decimal('26.0800'), 'Sim', 'Food and Drink', 5)

# %% [markdown]
# Por fim criamos o data frame e exportamos para CSV.

# %%
import pandas

dict_df = {'Nome_Filme' : titulo,
           'Preco' : preco,
           'Tem_estoque' : estoque,
           'Avaliacao' : avaliacao,
           'Estilo' : estilo}

Df_final = pd.DataFrame(dict_df) 

Df_final.to_csv()

# %%
Df_final.head()
# Out:
#                               Nome_Filme  Preco Tem_estoque  Avaliacao  \
# 0                   A Light in the Attic  51.77         Sim          3
# 1                     Tipping the Velvet  53.74         Sim          1
# 2                             Soumission  50.10         Sim          1
# 3                          Sharp Objects  47.82         Sim          4
# 4  Sapiens: A Brief History of Humankind  54.23         Sim          5
#
#                Estilo
# 0              Poetry
# 1  Historical Fiction
# 2             Fiction
# 3             Mystery
# 4             History

# %% [markdown]
# ## Visualização dos Dados
#
# Vamos fazer uma breve visualização dos dados, para ter uma noção de como esses dados estão dispostos.
#
# Podemos agrupar em tipos de estilos para ver a media do preço por estilo e das avaliações. Além disso podemos agrupar por avaliação paara esta conectado de alguma forma.

# %%
Group_estilo = Df_final.groupby('Estilo')

# %%
Group_estilo2 = Group_estilo.mean()
Group_estilo2['Count'] = Group_estilo.count()['Preco']

# %%
Group_estilo2.head(10)
# Out:
#                        Preco  Avaliacao  Count
# Estilo
# Academic           13.120000   2.000000      1
# Add a comment      35.796418   2.761194     67
# Adult Fiction      15.360000   5.000000      1
# Art                38.520000   3.625000      8
# Autobiography      37.053333   3.000000      9
# Biography          33.662000   2.200000      5
# Business           32.460000   2.916667     12
# Childrens          32.638276   2.620690     29
# Christian          42.496667   2.666667      3
# Christian Fiction  34.385000   4.166667      6

# %% [markdown]
# Podemos observar pelos graficos que os estilos de suspense, novels e politics são com preços elevados, porém a maioria dos estilos tem uma quantidade superior a 30 reais, sendo os mais baratos custando apenas 10 reais. Com maiores avaliações são o Adult Fiction, Erotica e Novels, porém quando vemos a quantidade desses livros temos que tem apenas um exemplar. Os livros com as piores avaliaçoes são do tipo crime,cultural, paranormal e short stories que tambem tem apenas um exemplar.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fig,axis = plt.subplots(1,2,figsize = (15,12))

Group_estilo2['Preco'].sort_values().plot.barh(ax = axis[0]);
Group_estilo2['Avaliacao'].sort_values().plot.barh(ax = axis[1]);

plt.tight_layout(pad = 3)

# %% [markdown]
# Majoritariamente o estilo de livros é Default, que deve ser uma opção quando não se sabe ou não foi definido o estilo do livro. Podemos ver o proximo que mostra que nonfiction tambem com uma grande quantidade de livros, assim como sequential art.

# %%
Group_estilo2['Count'].sort_values().plot.barh(figsize = (15,10));

# %% [markdown]
# Vemos que todos os livros tem no estoque.

# %%
Df_final['Tem_estoque'].value_counts()
# Out:
# Sim    1000
# Name: Tem_estoque, dtype: int64

# %% [markdown]
# Agrupando nossos dados por avaliação
#
# Podemos ver que a avaliação não influencia no preço dos livros, todos estão proximos. Vemos que os livros com avaliação baixa é que tem em maior quantidade, porém as demais avaliações ficam proximas.

# %%
Group_aval = Df_final.groupby('Avaliacao')

Group_aval2 = Group_aval.mean()
Group_aval2['Count'] = Group_aval.count()['Preco']

# %%
Group_aval2.head(10)
# Out:
#                Preco  Count
# Avaliacao
# 1          34.561195    226
# 2          34.810918    196
# 3          34.692020    203
# 4          36.093296    179
# 5          35.374490    196

# %%
fig,axis = plt.subplots(1,2,figsize = (10,8))

Group_aval2['Preco'].plot(kind = 'bar',ax = axis[0]);
Group_aval2['Count'].plot(kind = 'bar',ax = axis[1]);

axis[0].set_title('Preço')
axis[1].set_title('Quantidade')

plt.tight_layout(pad = 3)

# %% [markdown]
# # Conclusão
#
# Esse projeto teve o intuito de mostrar ferramentas para fazer um web scrapy de paginas de internet para conseguir dados, dessa forma foi utilizado BeautifulSoup para pegar os dados e Selenium para passagem de pagina. Ao mesmo tempo que iamos colentando os dados, foi criado uma tabela dentro de um banco de dados para fazer a transferencia dos dados e por fim tambem exportamos para um csv.
#
# No final foi feito uma breve analise dos dados, porém nada muito profundo, só para ver o estado final dos dados.
